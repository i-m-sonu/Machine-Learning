# %%
import numpy as np
import pandas as pd
data=pd.read_json("test.json")

# %%
data.head(5)
# Out:
#                                     _id state_name district_name  \
# 0  {'$oid': '65bb952d68f7df19e60a56c6'}    Gujarat         Surat
# 1  {'$oid': '65bb952d68f7df19e60a56c7'}    Haryana       Sonipat
# 2  {'$oid': '65bb952d68f7df19e60a56c8'}  Telangana     Hyderabad
# 3  {'$oid': '65bb952d68f7df19e60a56c9'}  Telangana   Ranga Reddy
# 4  {'$oid': '65bb952d68f7df19e60a56ca'}    Gujarat         Surat
#
#                  market_name       variety       group  arrival_tonnes  \
# 0                      Surat         Other  Vegetables            1.50
# 1                     Ganaur  Yam (Ratalu)  Vegetables            0.45
# 2     Erragadda(Rythu Bazar)         Other  Vegetables            3.00
# 3  Mehndipatnam(Rythu Bazar)         Other  Vegetables            0.40
# 4                      Surat         Other  Vegetables            1.50
#
#    min_price_rs_quintal  max_price_rs_quintal  modal_price_rs_quintal  \
# 0                  4000                  7500                    5750
# ...

# %%
data
# Out:
#                                        _id state_name district_name  \
# 0     {'$oid': '65bb952d68f7df19e60a56c6'}    Gujarat         Surat
# 1     {'$oid': '65bb952d68f7df19e60a56c7'}    Haryana       Sonipat
# 2     {'$oid': '65bb952d68f7df19e60a56c8'}  Telangana     Hyderabad
# 3     {'$oid': '65bb952d68f7df19e60a56c9'}  Telangana   Ranga Reddy
# 4     {'$oid': '65bb952d68f7df19e60a56ca'}    Gujarat         Surat
# ...                                    ...        ...           ...
# 3435  {'$oid': '65bb952d68f7df19e60a6431'}     Kerala       Wayanad
# 3436  {'$oid': '65bb952d68f7df19e60a6432'}     Kerala        Idukki
# 3437  {'$oid': '65bb952d68f7df19e60a6433'}     Kerala        Kollam
# 3438  {'$oid': '65bb952d68f7df19e60a6434'}  Telangana     Hyderabad
# 3439  {'$oid': '65bb952d68f7df19e60a6435'}  Telangana   Ranga Reddy
#
#                     market_name       variety       group  arrival_tonnes  \
# 0                         Surat         Other  Vegetables            1.50
# ...

# %%
data.drop(['_id'], axis=1)
# Out:
#      state_name district_name                market_name       variety  \
# 0       Gujarat         Surat                      Surat         Other
# 1       Haryana       Sonipat                     Ganaur  Yam (Ratalu)
# 2     Telangana     Hyderabad     Erragadda(Rythu Bazar)         Other
# 3     Telangana   Ranga Reddy  Mehndipatnam(Rythu Bazar)         Other
# 4       Gujarat         Surat                      Surat         Other
# ...         ...           ...                        ...           ...
# 3435     Kerala       Wayanad                   Kalpetta         Other
# 3436     Kerala        Idukki                 Kattappana         Other
# 3437     Kerala        Kollam                     Kollam         Other
# 3438  Telangana     Hyderabad     Erragadda(Rythu Bazar)         Other
# 3439  Telangana   Ranga Reddy  Mehndipatnam(Rythu Bazar)         Other
#
#            group  arrival_tonnes  min_price_rs_quintal  max_price_rs_quintal  \
# ...

# %%
data
# Out:
#      state_name district_name                market_name  arrival_tonnes  \
# 0       Gujarat         Surat                      Surat            1.50
# 1       Haryana       Sonipat                     Ganaur            0.45
# 2     Telangana     Hyderabad     Erragadda(Rythu Bazar)            3.00
# 3     Telangana   Ranga Reddy  Mehndipatnam(Rythu Bazar)            0.40
# 4       Gujarat         Surat                      Surat            1.50
# ...         ...           ...                        ...             ...
# 3435     Kerala       Wayanad                   Kalpetta           13.00
# 3436     Kerala        Idukki                 Kattappana            4.90
# 3437     Kerala        Kollam                     Kollam            0.30
# 3438  Telangana     Hyderabad     Erragadda(Rythu Bazar)            3.00
# 3439  Telangana   Ranga Reddy  Mehndipatnam(Rythu Bazar)            0.30
#
#       min_price_rs_quintal  max_price_rs_quintal  modal_price_rs_quintal  \
# ...

# %%
data['reported_date'] = pd.to_datetime(data['reported_date'].apply(lambda x: x['$date']), format='%Y-%m-%dT%H:%M:%S.%fZ')
data
# data.to_json('modified_data.json', orient='records', lines=True)
# Out:
#      state_name district_name                market_name  arrival_tonnes  \
# 0       Gujarat         Surat                      Surat            1.50
# 1       Haryana       Sonipat                     Ganaur            0.45
# 2     Telangana     Hyderabad     Erragadda(Rythu Bazar)            3.00
# 3     Telangana   Ranga Reddy  Mehndipatnam(Rythu Bazar)            0.40
# 4       Gujarat         Surat                      Surat            1.50
# ...         ...           ...                        ...             ...
# 3435     Kerala       Wayanad                   Kalpetta           13.00
# 3436     Kerala        Idukki                 Kattappana            4.90
# 3437     Kerala        Kollam                     Kollam            0.30
# 3438  Telangana     Hyderabad     Erragadda(Rythu Bazar)            3.00
# 3439  Telangana   Ranga Reddy  Mehndipatnam(Rythu Bazar)            0.30
#
#       min_price_rs_quintal  max_price_rs_quintal  modal_price_rs_quintal  \
# ...

# %%
data.to_json('price.json', orient='records', lines=True)

# %%
import matplotlib.pyplot as plot
import numpy as np
import pandas as pd
data=pd.read_json("test.json")
plot.plot(data['state_name'],data['modal_price_rs_quintal'])
plot.show()

# %%
data
# Out:
#                                        _id state_name district_name  \
# 0     {'$oid': '65bb952d68f7df19e60a56c6'}    Gujarat         Surat
# 1     {'$oid': '65bb952d68f7df19e60a56c7'}    Haryana       Sonipat
# 2     {'$oid': '65bb952d68f7df19e60a56c8'}  Telangana     Hyderabad
# 3     {'$oid': '65bb952d68f7df19e60a56c9'}  Telangana   Ranga Reddy
# 4     {'$oid': '65bb952d68f7df19e60a56ca'}    Gujarat         Surat
# ...                                    ...        ...           ...
# 3435  {'$oid': '65bb952d68f7df19e60a6431'}     Kerala       Wayanad
# 3436  {'$oid': '65bb952d68f7df19e60a6432'}     Kerala        Idukki
# 3437  {'$oid': '65bb952d68f7df19e60a6433'}     Kerala        Kollam
# 3438  {'$oid': '65bb952d68f7df19e60a6434'}  Telangana     Hyderabad
# 3439  {'$oid': '65bb952d68f7df19e60a6435'}  Telangana   Ranga Reddy
#
#                     market_name       variety       group  arrival_tonnes  \
# 0                         Surat         Other  Vegetables            1.50
# ...
